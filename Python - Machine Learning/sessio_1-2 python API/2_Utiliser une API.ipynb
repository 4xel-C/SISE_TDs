# %% [markdown]
# # Extraction des données complètes pour le Rhones

# %%
import requests
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
import time

# URL de base de l'API
base_url = "https://data.ademe.fr/data-fair/api/v1/datasets/dpe03existant/lines"

# %%
# Chargement du ficher des adresses du rhones.
df69 = pd.read_csv("data/adresses-69.csv", sep=";", low_memory=False)

# %%
# Extraction des codes postaux.
code_postaux = df69["code_postal"].unique()

# %% [markdown]
# # Methode de requête de l'API

# %%
# Liste des codes qui n'ont pas pu être récupérés.
missed_codes = list()

def query_api(params: dict, base_url: str = base_url, next_url: str | None = None, retries: int = 3, backoff: int = 2) -> list[dict]:
    """Récupère toutes les pages d'une requête API en boucle avec gestion des erreurs."""

    all_results = []

    recuperated = 0

    # Recuperation du code postal des paramètres.
    postal_code = params["qs"].split(":")[-1]

    while True:
        for attempt in range(retries):
            try:
                if next_url:
                    response = requests.get(url=next_url)
                else:
                    response = requests.get(url=base_url, params=params)

                if response.status_code == 200:

                    content = response.json()

                    # Monitoring
                    recuperated += (content["total"]- recuperated) if (content["total"] - recuperated) < params["size"] else params["size"]

                    

                    if content["total"] == 0:
                        print("No data found from the query.", flush=True)
                        return []
                
                    
                    all_results.extend(content["results"])
                    print(f"{postal_code}: {recuperated} éléments sur {content["total"]} ({int(recuperated*100/content["total"])}%)", flush=True)

                    next_url = content.get("next")
                    break  # sortie du retry loop si succès

                # Gestion d'erreur si requête invalide.
                else:
                    print(f"{postal_code}: Erreur de connexion avec l'API!, tentative {attempt+1}/{retries}", flush=True)
                    time.sleep(backoff * (attempt + 1))  # backoff progressif

            # Gestion d'erreur si problème de connexion.
            except requests.RequestException as e:
                print(f"{postal_code}: Erreur réseau: {e}, tentative {attempt+1}/{retries}", flush=True)
                time.sleep(backoff * (attempt + 1))  # backoff progressif

        # else de boucle for (si trop d'échecs.)
        else:
            print(f"{postal_code}: Échec permanent, abandon de cette requête.")

            # Addition du code manqué dans le dictionnaire.
            missed_codes.append(postal_code)

            return all_results # Retourner les informations récupérés jusqu'à présent.

        if not next_url:
            break

    return all_results

# %% [markdown]
# ## Extraction normale

# %%
df_list = list()

for i, code in enumerate(code_postaux):

    print()
    print(f"==Récupération codes postaux: {i+1}/{len(code_postaux)}==")

    params = {
            "size": 1500,   
            "qs": f"code_postal_ban:{code}"
        }
    df_list.extend(query_api(params=params, retries=5))

# Concaténation de la liste de dictionnaire en dataframe.
df = pd.DataFrame(df_list)

df.to_csv("existants_69.csv")
# Out:
# ==Récupération codes postaux: 1/91==
# 69790: 197 éléments sur 197 (100%)
#
# ==Récupération codes postaux: 2/91==
# 69170: 1500 éléments sur 2893 (51%)
# 69170: 2893 éléments sur 2893 (100%)
#
# ==Récupération codes postaux: 3/91==
# 69250: 1500 éléments sur 3167 (47%)
# 69250: 3000 éléments sur 3167 (94%)
# 69250: 3167 éléments sur 3167 (100%)
#
# ==Récupération codes postaux: 4/91==
# 69380: 1500 éléments sur 3216 (46%)
# 69380: 3000 éléments sur 3216 (93%)
# 69380: 3216 éléments sur 3216 (100%)
#
# ==Récupération codes postaux: 5/91==
# 69009: 1500 éléments sur 21052 (7%)
# 69009: 3000 éléments sur 21052 (14%)
# 69009: 4500 éléments sur 21052 (21%)
# 69009: 6000 éléments sur 21052 (28%)
# 69009: 7500 éléments sur 21052 (35%)
# 69009: 9000 éléments sur 21052 (42%)
# 69009: 10500 éléments sur 21052 (49%)
# 69009: 12000 éléments sur 21052 (57%)
# 69009: 13500 éléments sur 21052 (64%)
# 69009: 15000 éléments sur 21052 (71%)
# 69009: 16500 éléments sur 21052 (78%)
# 69009: 18000 éléments sur 21052 (85%)
# 69009: 19500 éléments sur 21052 (92%)
# 69009: 21000 éléments sur 21052 (99%)
# 69009: 21052 éléments sur 21052 (100%)
#
# ==Récupération codes postaux: 6/91==
# 69008: 1500 éléments sur 24960 (6%)
# 69008: 3000 éléments sur 24960 (12%)
# 69008: 4500 éléments sur 24960 (18%)
# 69008: 6000 éléments sur 24960 (24%)
# 69008: 7500 éléments sur 24960 (30%)
# 69008: 9000 éléments sur 24960 (36%)
# 69008: 10500 éléments sur 24960 (42%)
# 69008: 12000 éléments sur 24960 (48%)
# 69008: 13500 éléments sur 24960 (54%)
# 69008: 15000 éléments sur 24960 (60%)
# 69008: 16500 éléments sur 24960 (66%)
# 69008: 18000 éléments sur 24960 (72%)
# 69008: 19500 éléments sur 24960 (78%)
# 69008: 21000 éléments sur 24960 (84%)
# 69008: 22500 éléments sur 24960 (90%)
# 69008: 24000 éléments sur 24960 (96%)
# 69008: 24960 éléments sur 24960 (100%)
#
# ==Récupération codes postaux: 7/91==
# 69006: 1500 éléments sur 15390 (9%)
# 69006: 3000 éléments sur 15390 (19%)
# 69006: 4500 éléments sur 15390 (29%)
# 69006: 6000 éléments sur 15390 (38%)
# 69006: 7500 éléments sur 15390 (48%)
# 69006: 9000 éléments sur 15390 (58%)
# 69006: 10500 éléments sur 15390 (68%)
# 69006: 12000 éléments sur 15390 (77%)
# 69006: 13500 éléments sur 15390 (87%)
# 69006: 15000 éléments sur 15390 (97%)
# 69006: 15390 éléments sur 15390 (100%)
#
# ==Récupération codes postaux: 8/91==
# 69007: 1500 éléments sur 33057 (4%)
# 69007: 3000 éléments sur 33057 (9%)
# 69007: 4500 éléments sur 33057 (13%)
# 69007: 6000 éléments sur 33057 (18%)
# 69007: 7500 éléments sur 33057 (22%)
# 69007: 9000 éléments sur 33057 (27%)
# 69007: 10500 éléments sur 33057 (31%)
# 69007: 12000 éléments sur 33057 (36%)
# 69007: 13500 éléments sur 33057 (40%)
# 69007: 15000 éléments sur 33057 (45%)
# 69007: 16500 éléments sur 33057 (49%)
# 69007: 18000 éléments sur 33057 (54%)
# 69007: 19500 éléments sur 33057 (58%)
# 69007: 21000 éléments sur 33057 (63%)
# 69007: 22500 éléments sur 33057 (68%)
# 69007: 24000 éléments sur 33057 (72%)
# 69007: 25500 éléments sur 33057 (77%)
# 69007: 27000 éléments sur 33057 (81%)
# 69007: 28500 éléments sur 33057 (86%)
# 69007: 30000 éléments sur 33057 (90%)
# 69007: 31500 éléments sur 33057 (95%)
# 69007: 33000 éléments sur 33057 (99%)
# 69007: 33057 éléments sur 33057 (100%)
#
# ==Récupération codes postaux: 9/91==
# 69005: 1500 éléments sur 19127 (7%)
# 69005: 3000 éléments sur 19127 (15%)
# 69005: 4500 éléments sur 19127 (23%)
# 69005: 6000 éléments sur 19127 (31%)
# 69005: 7500 éléments sur 19127 (39%)
# 69005: 9000 éléments sur 19127 (47%)
# 69005: 10500 éléments sur 19127 (54%)
# 69005: 12000 éléments sur 19127 (62%)
# 69005: 13500 éléments sur 19127 (70%)
# 69005: 15000 éléments sur 19127 (78%)
# 69005: 16500 éléments sur 19127 (86%)
# 69005: 18000 éléments sur 19127 (94%)
# 69005: 19127 éléments sur 19127 (100%)
#
# ==Récupération codes postaux: 10/91==
# 69001: 1500 éléments sur 11153 (13%)
# 69001: 3000 éléments sur 11153 (26%)
# 69001: 4500 éléments sur 11153 (40%)
# 69001: 6000 éléments sur 11153 (53%)
# 69001: 7500 éléments sur 11153 (67%)
# 69001: 9000 éléments sur 11153 (80%)
# 69001: 10500 éléments sur 11153 (94%)
# 69001: 11153 éléments sur 11153 (100%)
#
# ==Récupération codes postaux: 11/91==
# 69004: 1500 éléments sur 9856 (15%)
# 69004: 3000 éléments sur 9856 (30%)
# 69004: 4500 éléments sur 9856 (45%)
# 69004: 6000 éléments sur 9856 (60%)
# 69004: 7500 éléments sur 9856 (76%)
# 69004: 9000 éléments sur 9856 (91%)
# 69004: 9856 éléments sur 9856 (100%)
#
# ==Récupération codes postaux: 12/91==
# 69002: 1500 éléments sur 12745 (11%)
# 69002: 3000 éléments sur 12745 (23%)
# 69002: 4500 éléments sur 12745 (35%)
# 69002: 6000 éléments sur 12745 (47%)
# 69002: 7500 éléments sur 12745 (58%)
# 69002: 9000 éléments sur 12745 (70%)
# 69002: 10500 éléments sur 12745 (82%)
# 69002: 12000 éléments sur 12745 (94%)
# 69002: 12745 éléments sur 12745 (100%)
#
# ==Récupération codes postaux: 13/91==
# 69003: 1500 éléments sur 30348 (4%)
# 69003: 3000 éléments sur 30348 (9%)
# 69003: 4500 éléments sur 30348 (14%)
# 69003: 6000 éléments sur 30348 (19%)
# 69003: 7500 éléments sur 30348 (24%)
# 69003: 9000 éléments sur 30348 (29%)
# 69003: 10500 éléments sur 30348 (34%)
# 69003: 12000 éléments sur 30348 (39%)
# 69003: 13500 éléments sur 30348 (44%)
# 69003: 15000 éléments sur 30348 (49%)
# 69003: 16500 éléments sur 30348 (54%)
# 69003: 18000 éléments sur 30348 (59%)
# 69003: 19500 éléments sur 30348 (64%)
# 69003: 21000 éléments sur 30348 (69%)
# 69003: 22500 éléments sur 30348 (74%)
# 69003: 24000 éléments sur 30348 (79%)
# 69003: 25500 éléments sur 30348 (84%)
# 69003: 27000 éléments sur 30348 (88%)
# 69003: 28500 éléments sur 30348 (93%)
# 69003: 30000 éléments sur 30348 (98%)
# 69003: 30348 éléments sur 30348 (100%)
#
# ==Récupération codes postaux: 14/91==
# 69780: 1500 éléments sur 2254 (66%)
# 69780: 2254 éléments sur 2254 (100%)
#
# ==Récupération codes postaux: 15/91==
# 69360: 1500 éléments sur 2828 (53%)
# 69360: 2828 éléments sur 2828 (100%)
#
# ==Récupération codes postaux: 16/91==
# 69124: 268 éléments sur 268 (100%)
#
# ==Récupération codes postaux: 17/91==
# 69580: 968 éléments sur 968 (100%)
#
# ==Récupération codes postaux: 18/91==
# 69720: 1193 éléments sur 1193 (100%)
#
# ==Récupération codes postaux: 19/91==
# 69960: 1413 éléments sur 1413 (100%)
#
# ==Récupération codes postaux: 20/91==
# 69320: 1500 éléments sur 1950 (76%)
# 69320: 1950 éléments sur 1950 (100%)
#
# ==Récupération codes postaux: 21/91==
# 69800: 1500 éléments sur 6407 (23%)
# 69800: 3000 éléments sur 6407 (46%)
# 69800: 4500 éléments sur 6407 (70%)
# 69800: 6000 éléments sur 6407 (93%)
# 69800: 6407 éléments sur 6407 (100%)
#
# ==Récupération codes postaux: 22/91==
# 69140: 1500 éléments sur 9402 (15%)
# 69140: 3000 éléments sur 9402 (31%)
# 69140: 4500 éléments sur 9402 (47%)
# 69140: 6000 éléments sur 9402 (63%)
# 69140: 7500 éléments sur 9402 (79%)
# 69140: 9000 éléments sur 9402 (95%)
# 69140: 9402 éléments sur 9402 (100%)
#
# ==Récupération codes postaux: 23/91==
# 69330: 1500 éléments sur 5758 (26%)
# 69330: 3000 éléments sur 5758 (52%)
# 69330: 4500 éléments sur 5758 (78%)
# 69330: 5758 éléments sur 5758 (100%)
#
# ==Récupération codes postaux: 24/91==
# 69970: 674 éléments sur 674 (100%)
#
# ==Récupération codes postaux: 25/91==
# 69730: 1052 éléments sur 1052 (100%)
#
# ==Récupération codes postaux: 26/91==
# 69740: 1397 éléments sur 1397 (100%)
#
# ==Récupération codes postaux: 27/91==
# 69150: 1500 éléments sur 5508 (27%)
# 69150: 3000 éléments sur 5508 (54%)
# 69150: 4500 éléments sur 5508 (81%)
# 69150: 5508 éléments sur 5508 (100%)
#
# ==Récupération codes postaux: 28/91==
# 69680: 1210 éléments sur 1210 (100%)
#
# ==Récupération codes postaux: 29/91==
# 69510: 1437 éléments sur 1437 (100%)
#
# ==Récupération codes postaux: 30/91==
# 69390: 1500 éléments sur 2199 (68%)
# 69390: 2199 éléments sur 2199 (100%)
#
# ==Récupération codes postaux: 31/91==
# 69910: 176 éléments sur 176 (100%)
#
# ==Récupération codes postaux: 32/91==
# 69100: 1500 éléments sur 41822 (3%)
# 69100: 3000 éléments sur 41822 (7%)
# 69100: 4500 éléments sur 41822 (10%)
# 69100: 6000 éléments sur 41822 (14%)
# 69100: 7500 éléments sur 41822 (17%)
# 69100: 9000 éléments sur 41822 (21%)
# 69100: 10500 éléments sur 41822 (25%)
# 69100: 12000 éléments sur 41822 (28%)
# 69100: 13500 éléments sur 41822 (32%)
# 69100: 15000 éléments sur 41822 (35%)
# 69100: 16500 éléments sur 41822 (39%)
# 69100: 18000 éléments sur 41822 (43%)
# 69100: 19500 éléments sur 41822 (46%)
# 69100: 21000 éléments sur 41822 (50%)
# 69100: 22500 éléments sur 41822 (53%)
# 69100: 24000 éléments sur 41822 (57%)
# 69100: 25500 éléments sur 41822 (60%)
# 69100: 27000 éléments sur 41822 (64%)
# 69100: 28500 éléments sur 41822 (68%)
# 69100: 30000 éléments sur 41822 (71%)
# 69100: 31500 éléments sur 41822 (75%)
# 69100: 33000 éléments sur 41822 (78%)
# 69100: 34500 éléments sur 41822 (82%)
# 69100: 36000 éléments sur 41822 (86%)
# 69100: 37500 éléments sur 41822 (89%)
# 69100: 39000 éléments sur 41822 (93%)
# 69100: 40500 éléments sur 41822 (96%)
# 69100: 41822 éléments sur 41822 (100%)
#
# ==Récupération codes postaux: 33/91==
# 69640: 676 éléments sur 676 (100%)
#
# ==Récupération codes postaux: 34/91==
# 69770: 289 éléments sur 289 (100%)
#
# ==Récupération codes postaux: 35/91==
# 69400: 1500 éléments sur 12557 (11%)
# 69400: 3000 éléments sur 12557 (23%)
# 69400: 4500 éléments sur 12557 (35%)
# 69400: 6000 éléments sur 12557 (47%)
# 69400: 7500 éléments sur 12557 (59%)
# 69400: 9000 éléments sur 12557 (71%)
# 69400: 10500 éléments sur 12557 (83%)
# 69400: 12000 éléments sur 12557 (95%)
# 69400: 12557 éléments sur 12557 (100%)
#
# ==Récupération codes postaux: 36/91==
# 69430: 997 éléments sur 997 (100%)
#
# ==Récupération codes postaux: 37/91==
# 69820: 185 éléments sur 185 (100%)
#
# ==Récupération codes postaux: 38/91==
# 69460: 977 éléments sur 977 (100%)
#
# ==Récupération codes postaux: 39/91==
# 69200: 1500 éléments sur 18048 (8%)
# 69200: 3000 éléments sur 18048 (16%)
# 69200: 4500 éléments sur 18048 (24%)
# 69200: 6000 éléments sur 18048 (33%)
# 69200: 7500 éléments sur 18048 (41%)
# 69200: 9000 éléments sur 18048 (49%)
# 69200: 10500 éléments sur 18048 (58%)
# 69200: 12000 éléments sur 18048 (66%)
# 69200: 13500 éléments sur 18048 (74%)
# 69200: 15000 éléments sur 18048 (83%)
# 69200: 16500 éléments sur 18048 (91%)
# 69200: 18000 éléments sur 18048 (99%)
# 69200: 18048 éléments sur 18048 (100%)
#
# ==Récupération codes postaux: 40/91==
# 69120: 1500 éléments sur 8706 (17%)
# 69120: 3000 éléments sur 8706 (34%)
# 69120: 4500 éléments sur 8706 (51%)
# 69120: 6000 éléments sur 8706 (68%)
# 69120: 7500 éléments sur 8706 (86%)
# 69120: 8706 éléments sur 8706 (100%)
#
# ==Récupération codes postaux: 41/91==
# 69420: 1099 éléments sur 1099 (100%)
#
# ==Récupération codes postaux: 42/91==
# 69670: 569 éléments sur 569 (100%)
#
# ==Récupération codes postaux: 43/91==
# 69890: 671 éléments sur 671 (100%)
#
# ==Récupération codes postaux: 44/91==
# 69620: 1205 éléments sur 1205 (100%)
#
# ==Récupération codes postaux: 45/91==
# 69240: 825 éléments sur 825 (100%)
#
# ==Récupération codes postaux: 46/91==
# 69160: 1500 éléments sur 4607 (32%)
# 69160: 3000 éléments sur 4607 (65%)
# 69160: 4500 éléments sur 4607 (97%)
# 69160: 4607 éléments sur 4607 (100%)
#
# ==Récupération codes postaux: 47/91==
# 69220: 1500 éléments sur 2805 (53%)
# 69220: 2805 éléments sur 2805 (100%)
#
# ==Récupération codes postaux: 48/91==
# 69440: 1500 éléments sur 1818 (82%)
# 69440: 1818 éléments sur 1818 (100%)
#
# ==Récupération codes postaux: 49/91==
# 69490: 976 éléments sur 976 (100%)
#
# ==Récupération codes postaux: 50/91==
# 69700: 1500 éléments sur 5543 (27%)
# 69700: 3000 éléments sur 5543 (54%)
# 69700: 4500 éléments sur 5543 (81%)
# 69700: 5543 éléments sur 5543 (100%)
#
# ==Récupération codes postaux: 51/91==
# 69560: 710 éléments sur 710 (100%)
#
# ==Récupération codes postaux: 52/91==
# 69590: 909 éléments sur 909 (100%)
#
# ==Récupération codes postaux: 53/91==
# 69270: 1500 éléments sur 2424 (61%)
# 69270: 2424 éléments sur 2424 (100%)
#
# ==Récupération codes postaux: 54/91==
# 69870: 768 éléments sur 768 (100%)
#
# ==Récupération codes postaux: 55/91==
# 69210: 1500 éléments sur 3747 (40%)
# 69210: 3000 éléments sur 3747 (80%)
# 69210: 3747 éléments sur 3747 (100%)
#
# ==Récupération codes postaux: 56/91==
# 69850: 457 éléments sur 457 (100%)
#
# ==Récupération codes postaux: 57/91==
# 69930: 275 éléments sur 275 (100%)
#
# ==Récupération codes postaux: 58/91==
# 69690: 635 éléments sur 635 (100%)
#
# ==Récupération codes postaux: 59/91==
# 69550: 922 éléments sur 922 (100%)
#
# ==Récupération codes postaux: 60/91==
# 69650: 1038 éléments sur 1038 (100%)
#
# ==Récupération codes postaux: 61/91==
# 69830: 552 éléments sur 552 (100%)
#
# ==Récupération codes postaux: 62/91==
# 69290: 1500 éléments sur 4229 (35%)
# 69290: 3000 éléments sur 4229 (70%)
# 69290: 4229 éléments sur 4229 (100%)
#
# ==Récupération codes postaux: 63/91==
# 69230: 1500 éléments sur 3566 (42%)
# 69230: 3000 éléments sur 3566 (84%)
# 69230: 3566 éléments sur 3566 (100%)
#
# ==Récupération codes postaux: 64/91==
# 69610: 765 éléments sur 765 (100%)
#
# ==Récupération codes postaux: 65/91==
# 69110: 1500 éléments sur 3686 (40%)
# 69110: 3000 éléments sur 3686 (81%)
# 69110: 3686 éléments sur 3686 (100%)
#
# ==Récupération codes postaux: 66/91==
# 69190: 1500 éléments sur 4587 (32%)
# 69190: 3000 éléments sur 4587 (65%)
# 69190: 4500 éléments sur 4587 (98%)
# 69190: 4587 éléments sur 4587 (100%)
#
# ==Récupération codes postaux: 67/91==
# 69450: 879 éléments sur 879 (100%)
#
# ==Récupération codes postaux: 68/91==
# 69370: 964 éléments sur 964 (100%)
#
# ==Récupération codes postaux: 69/91==
# 69280: 672 éléments sur 672 (100%)
#
# ==Récupération codes postaux: 70/91==
# 69470: 739 éléments sur 739 (100%)
#
# ==Récupération codes postaux: 71/91==
# 69480: 1500 éléments sur 2073 (72%)
# 69480: 2073 éléments sur 2073 (100%)
#
# ==Récupération codes postaux: 72/91==
# 69530: 1500 éléments sur 1818 (82%)
# 69530: 1818 éléments sur 1818 (100%)
#
# ==Récupération codes postaux: 73/91==
# 69310: 1500 éléments sur 1887 (79%)
# 69310: 1887 éléments sur 1887 (100%)
#
# ==Récupération codes postaux: 74/91==
# 69600: 1500 éléments sur 6524 (22%)
# 69600: 3000 éléments sur 6524 (45%)
# 69600: 4500 éléments sur 6524 (68%)
# 69600: 6000 éléments sur 6524 (91%)
# 69600: 6524 éléments sur 6524 (100%)
#
# ==Récupération codes postaux: 75/91==
# 69350: 1491 éléments sur 1491 (100%)
#
# ==Récupération codes postaux: 76/91==
# 69860: 219 éléments sur 219 (100%)
#
# ==Récupération codes postaux: 77/91==
# 69760: 867 éléments sur 867 (100%)
#
# ==Récupération codes postaux: 78/91==
# 69840: 301 éléments sur 301 (100%)
#
# ==Récupération codes postaux: 79/91==
# 69540: 1411 éléments sur 1411 (100%)
#
# ==Récupération codes postaux: 80/91==
# 69520: 1500 éléments sur 1785 (84%)
# 69520: 1785 éléments sur 1785 (100%)
#
# ==Récupération codes postaux: 81/91==
# 69340: 1500 éléments sur 2692 (55%)
# 69340: 2692 éléments sur 2692 (100%)
#
# ==Récupération codes postaux: 82/91==
# 69130: 1500 éléments sur 4273 (35%)
# 69130: 3000 éléments sur 4273 (70%)
# 69130: 4273 éléments sur 4273 (100%)
#
# ==Récupération codes postaux: 83/91==
# 69570: 1227 éléments sur 1227 (100%)
#
# ==Récupération codes postaux: 84/91==
# 69660: 697 éléments sur 697 (100%)
#
# ==Récupération codes postaux: 85/91==
# 69115: 42 éléments sur 42 (100%)
#
# ==Récupération codes postaux: 86/91==
# 69260: 820 éléments sur 820 (100%)
#
# ==Récupération codes postaux: 87/91==
# 69410: 1500 éléments sur 1616 (92%)
# 69410: 1616 éléments sur 1616 (100%)
#
# ==Récupération codes postaux: 88/91==
# 69630: 1050 éléments sur 1050 (100%)
#
# ==Récupération codes postaux: 89/91==
# 69300: 1500 éléments sur 9966 (15%)
# 69300: 3000 éléments sur 9966 (30%)
# 69300: 4500 éléments sur 9966 (45%)
# 69300: 6000 éléments sur 9966 (60%)
# 69300: 7500 éléments sur 9966 (75%)
# 69300: 9000 éléments sur 9966 (90%)
# 69300: 9966 éléments sur 9966 (100%)
#
# ==Récupération codes postaux: 90/91==
# 69500: 1500 éléments sur 8049 (18%)
# 69500: 3000 éléments sur 8049 (37%)
# 69500: 4500 éléments sur 8049 (55%)
# 69500: 6000 éléments sur 8049 (74%)
# 69500: 7500 éléments sur 8049 (93%)
# 69500: 8049 éléments sur 8049 (100%)
#
# ==Récupération codes postaux: 91/91==
# 69126: 695 éléments sur 695 (100%)

# %% [markdown]
# ## Multitreading code

# %% [markdown]
# Le code finit en erreur, car trop de requêtes simultannées sont demandées à l'API (l'API coupe la connection).

# %%
# def fetch_for_code(code):
#     """Exécute query_api pour un code postal donné."""
#     params = {
#         "size": 750,
#         "page": 1,
#         "qs": f"code_postal_ban:{code}"
#     }
#     return query_api(params=params, retries=5)


# # Liste des DataFrames pour tous les codes postaux
# with ThreadPoolExecutor(max_workers=10) as executor: 
#     all_lists = list(executor.map(fetch_for_code, code_postaux))

# list_to_df = []
# for sublist in all_lists:
#     list_to_df.extend(sublist)

# # Concaténation finale
# df_final = pd.DataFrame(list_to_df)

# # Ecriture.
# df_final.to_csv("existants_69.csv")

# %%
# # Vérification de l'extraction.
# df = pd.read_csv("existants_69.csv", index_col=0)

# %% [markdown]
# # Batiment neuf

# %% [markdown]
# Utiliser l'URL suivante: https://data.ademe.fr/data-fair/api/v1/datasets/dpe02neuf/lines

# %%
# Récupération des logements neufs.
new_habitation_list = list()

base_url = "https://data.ademe.fr/data-fair/api/v1/datasets/dpe02neuf/lines"

for i, code in enumerate(code_postaux):

    print()
    print(f"==Récupération codes postaux: {i+1}/{len(code_postaux)}==")

    params = {
            "size": 1500,   
            "qs": f"code_postal_ban:{code}"
        }

    new_habitation_list.extend(query_api(params=params))

# Concaténation de la liste de dictionnaire en dataframe.
df_news = pd.DataFrame(df_list)

# Ecriture du fichier en csv.
df_news.to_csv("neufs_69.csv")

# %% [markdown]
# # Concaténation des bâtiments existants et neufs.

# %%
# Relecture des fichiers csv si nécessaires.
df1 = pd.read_csv("existants_69.csv")
# Out:
# C:\Users\axel-\AppData\Local\Temp\ipykernel_167376\609199760.py:2: DtypeWarning: Columns (41,183,184,186,189,204,205,212,214) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("existants_69.csv")

# %%
# neufs
df2 = pd.read_csv("neufs_69.csv")
# Out:
# C:\Users\axel-\AppData\Local\Temp\ipykernel_167376\2481822624.py:2: DtypeWarning: Columns (41,183,184,186,189,204,205,212,214) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("neufs_69.csv")

# %%
# Effectuer la concaténation des deux dataframes.
df = pd.concat([df1, df2], join="inner")

# %%
# Exports du resultat final.
df.to_csv("logements_69.csv")

# %% [markdown]
# # Extraction des données d'ENEDIS de consommation par adresse.

# %%
# Ouverture du fichier d'ENEDIS.
df_enedis = pd.read_csv("data/consommation-annuelle-residentielle-par-adresse-69008.csv", sep=";")

# %%
df_enedis
# Out:
#       Unnamed: 0  annee  code_iris              nom_iris  numero_de_voie  \
# 0          66969   2022  693880202  Les Alouettes-Bachut            54.0
# 1          66978   2022  693880202  Les Alouettes-Bachut            49.0
# 2          66979   2022  693880102               Colbert             3.0
# 3          66980   2022  693880104   Marius Berliet Nord            26.0
# 4          66981   2022  693880101           Jean Moulin             2.0
# ...          ...    ...        ...                   ...             ...
# 9307     2368625   2023  693880204       Montplaisir Sud            10.0
# 9308     2368636   2023  693880302  Rockefeller-La Buire           127.0
# 9309     2368637   2023  693880302  Rockefeller-La Buire           123.0
# 9310     2368638   2023  693880302  Rockefeller-La Buire           113.0
# 9311     2368639   2023  693880302  Rockefeller-La Buire            81.0
#
#      indice_de_repetition type_de_voie   libelle_de_voie  code_commune  \
# 0                       B          RUE     SAINT MATHIEU         69123
# 1                     NaN          RUE      SAINT NESTOR         69123
# 2                     NaN          RUE      SAINT NESTOR         69123
# 3                     NaN          RUE      SAINT NESTOR         69123
# 4                     NaN          RUE      SAINT NESTOR         69123
# ...                   ...          ...               ...           ...
# 9307                  NaN    PROMENADE  L ET N BULLUKIAN         69123
# 9308                  NaN          RUE           LAENNEC         69123
# 9309                  NaN          RUE           LAENNEC         69123
# 9310                  NaN          RUE           LAENNEC         69123
# 9311                    C          RUE           LAENNEC         69123
#
#      nom_commune segment_de_client  nombre_de_logements  \
# 0           Lyon       RESIDENTIEL                   17
# 1           Lyon       RESIDENTIEL                   25
# 2           Lyon       RESIDENTIEL                  123
# 3           Lyon       RESIDENTIEL                   35
# 4           Lyon       RESIDENTIEL                   11
# ...          ...               ...                  ...
# 9307        Lyon       RESIDENTIEL                   56
# 9308        Lyon       RESIDENTIEL                   16
# 9309        Lyon       RESIDENTIEL                   14
# 9310        Lyon       RESIDENTIEL                   13
# 9311        Lyon       RESIDENTIEL                   16
#
#       consommation_annuelle_totale_de_l_adresse_mwh  \
# 0                                           109.700
# 1                                            95.018
# 2                                           244.940
# 3                                           164.746
# 4                                            21.472
# ...                                             ...
# 9307                                         65.831
# 9308                                         25.171
# 9309                                         31.795
# 9310                                         25.944
# 9311                                         38.102
#
#       consommation_annuelle_moyenne_par_site_de_l_adresse_mwh  \
# 0                                                 6.453
# 1                                                 3.801
# 2                                                 1.991
# 3                                                 4.707
# 4                                                 1.952
# ...                                                 ...
# 9307                                              1.176
# 9308                                              1.573
# 9309                                              2.271
# 9310                                              1.996
# 9311                                              2.381
#
#       consommation_annuelle_moyenne_de_la_commune_mwh  \
# 0                                               2.771
# 1                                               2.771
# 2                                               2.771
# 3                                               2.771
# 4                                               2.771
# ...                                               ...
# 9307                                            2.654
# 9308                                            2.654
# 9309                                            2.654
# 9310                                            2.654
# 9311                                            2.654
#
#                             adresse    code_epci  code_departement  \
# 0            54 B RUE SAINT MATHIEU  200046977.0              69.0
# 1               49 RUE SAINT NESTOR  200046977.0              69.0
# 2                3 RUE SAINT NESTOR  200046977.0              69.0
# 3               26 RUE SAINT NESTOR  200046977.0              69.0
# 4                2 RUE SAINT NESTOR  200046977.0              69.0
# ...                             ...          ...               ...
# 9307  10 PROMENADE L ET N BULLUKIAN  200046977.0              69.0
# 9308                127 RUE LAENNEC  200046977.0              69.0
# 9309                123 RUE LAENNEC  200046977.0              69.0
# 9310                113 RUE LAENNEC  200046977.0              69.0
# 9311               81 C RUE LAENNEC  200046977.0              69.0
#
#       code_region  tri_des_adresses
# 0            84.0            170031
# 1            84.0            170101
# 2            84.0            170106
# 3            84.0            170109
# 4            84.0            170111
# ...           ...               ...
# 9307         84.0            169802
# 9308         84.0            169886
# 9309         84.0            169888
# 9310         84.0            169893
# 9311         84.0            169902
#
# [9312 rows x 20 columns]

# %%
# Utilisation de l'API d'ENEDIS

def query_enedis_api(params: dict, base_url: str = base_url, retries: int = 3, backoff: int = 2) -> list[dict]:
    """Récupère toutes les pages d'une requête API en boucle avec gestion des erreurs."""

    # Create a copy of the parameters.
    params_local = params.copy()
    all_results = []

    recuperated = 0
    n = params_local["limit"]
    total = None
    params_local["offset"] = 0

    while True:
        for attempt in range(retries):
            try:
                response = requests.get(url=base_url, params=params_local)

                if response.status_code == 200:

                    content = response.json()

                    # Check if the query have found data.
                    if content["total_count"] == 0:
                        print("No data found from the query.", flush=True)
                        return []


                    # Monitoring.

                    # Update the count of total and recuperated.
                    if not total:
                        total = content["total_count"]
                    
                    total = total - n if total - n > 0 else 0
                    recuperated = recuperated + n if total - n > 0 else recuperated + total

                    # Add the result to the list.
                    all_results.extend(content["results"])

                    print(f"{recuperated}/{content["total_count"]} éléments récupérés ({int(recuperated*100/content["total_count"])}%)", flush=True)

                    # Rajotuer l'offset
                    params_local["offset"] += n

                    break  # sortie du retry loop si succès

                # Gestion d'erreur si requête invalide.
                else:
                    print(f"Erreur de connexion avec l'API!, tentative {attempt+1}/{retries}", flush=True)
                    time.sleep(backoff * (attempt + 1))  # backoff progressif

            # Gestion d'erreur si problème de connexion.
            except requests.RequestException as e:
                print(f"Erreur réseau: {e}, tentative {attempt+1}/{retries}", flush=True)
                time.sleep(backoff * (attempt + 1))  # backoff progressif

        # else de boucle for (si trop d'échecs.)
        else:
            print("Échec permanent, abandon de cette requête.")

            return all_results # Retourner les informations récupérés jusqu'à présent.

        # arrêt de la boucle si tout a été extrait.
        if total == 0:
            break

        # endfor
    
    # endwhile

    return all_results

# %%
base_url="https://data.enedis.fr/api/explore/v2.1/"
dataset= "consommation-annuelle-residentielle-par-adresse"
url=base_url + f"catalog/datasets/{dataset}/records"

# %%
# Test de requete
response = requests.get(
    url=url,
    params={
        "limit": 100,
        "where": f'code_commune=69006 and nom_commune like "Amplepuis"'
    }
    )

if response.status_code == 200:
    content = response.json()
else:
    print(response)

# %%
pd.DataFrame(content["results"])
# Out:
#    annee  code_iris nom_iris  numero_de_voie indice_de_repetition  \
# 0   2022  690060102  Contour               2                 None
# 1   2022  690060101   Centre              12                 None
# 2   2020  690060101   Centre               4                 None
# 3   2024  690060102  Contour              35                 None
# 4   2024  690060101   Centre              41                 None
# ..   ...        ...      ...             ...                  ...
# 95  2019  690060101   Centre              11                 None
# 96  2021  690060101   Centre              17                 None
# 97  2021  690060102  Contour               5                 None
# 98  2024  690060102  Contour               4                 None
# 99  2024  690060102  Contour               3                 None
#
#    type_de_voie    libelle_de_voie code_commune nom_commune segment_de_client  \
# 0           RUE      JOSEPH VIGNON        69006   Amplepuis       RESIDENTIEL
# 1           RUE  PAUL DE LA GOUTTE        69006   Amplepuis       RESIDENTIEL
# 2    ROND POINT        DE LA FERME        69006   Amplepuis       RESIDENTIEL
# 3           RUE      AUGUSTE VILLY        69006   Amplepuis       RESIDENTIEL
# 4      LIEU DIT         LE REVERDY        69006   Amplepuis       RESIDENTIEL
# ..          ...                ...          ...         ...               ...
# 95     LIEU DIT         LE REVERDY        69006   Amplepuis       RESIDENTIEL
# 96          RUE      DES FONTAINES        69006   Amplepuis       RESIDENTIEL
# 97          RUE      JOSEPH VIGNON        69006   Amplepuis       RESIDENTIEL
# 98          RUE      JOSEPH VIGNON        69006   Amplepuis       RESIDENTIEL
# 99          RUE      JOSEPH VIGNON        69006   Amplepuis       RESIDENTIEL
#
#     nombre_de_logements  consommation_annuelle_totale_de_l_adresse_mwh  \
# 0                    10                                         14.096
# 1                    24                                         36.461
# 2                    22                                         75.270
# 3                    10                                         44.014
# 4                    11                                         15.136
# ..                  ...                                            ...
# 95                   12                                         18.020
# 96                   31                                         55.070
# 97                   10                                         14.067
# 98                   10                                         12.887
# 99                   10                                         26.742
#
#     consommation_annuelle_moyenne_par_site_de_l_adresse_mwh  \
# 0                                               1.410
# 1                                               1.519
# 2                                               3.421
# 3                                               4.401
# 4                                               1.376
# ..                                                ...
# 95                                              1.502
# 96                                              1.776
# 97                                              1.407
# 98                                              1.289
# 99                                              2.674
#
#     consommation_annuelle_moyenne_de_la_commune_mwh                   adresse  \
# 0                                             4.069       2 RUE JOSEPH VIGNON
# 1                                             4.069  12 RUE PAUL DE LA GOUTTE
# 2                                             4.238  4 ROND POINT DE LA FERME
# 3                                             3.921      35 RUE AUGUSTE VILLY
# 4                                             3.921    41 LIEU DIT LE REVERDY
# ..                                              ...                       ...
# 95                                            4.214    11 LIEU DIT LE REVERDY
# 96                                            4.496      17 RUE DES FONTAINES
# 97                                            4.496       5 RUE JOSEPH VIGNON
# 98                                            3.921       4 RUE JOSEPH VIGNON
# 99                                            3.921       3 RUE JOSEPH VIGNON
#
#     code_epci code_departement code_region  tri_des_adresses
# 0   200040566               69          84              7318
# 1   200040566               69          84              7323
# 2   200040566               69          84              7228
# 3   200040566               69          84              7609
# 4   200040566               69          84              7621
# ..        ...              ...         ...               ...
# 95  200040566               69          84              7065
# 96  200040566               69          84              7234
# 97  200040566               69          84              7239
# 98  200040566               69          84              7617
# 99  200040566               69          84              7618
#
# [100 rows x 19 columns]

# %%
enedis_data = []

# Boucle pour requêter tous les codes postaux du département de rhone alpes.
for i, code in enumerate(code_postaux):

    print()
    print(f"==Récupération codes postaux: {i+1}/{len(code_postaux)}==")

    params = {
        "limit": 100,
        "where": f'code_commune={code}'
    }

    enedis_data.extend(query_enedis_api(base_url=url, params=params))
# Out:
# ==Récupération codes postaux: 1/91==
# No data found from the query.
#
# ==Récupération codes postaux: 2/91==
# 0/6 éléments récupérés (0%)
#
# ==Récupération codes postaux: 3/91==
# 44/144 éléments récupérés (30%)
# 44/144 éléments récupérés (30%)
#
# ==Récupération codes postaux: 4/91==
# No data found from the query.
#
# ==Récupération codes postaux: 5/91==
# 100/238 éléments récupérés (42%)
# 138/238 éléments récupérés (57%)
# 138/238 éléments récupérés (57%)
#
# ==Récupération codes postaux: 6/91==
# No data found from the query.
#
# ==Récupération codes postaux: 7/91==
# 0/100 éléments récupérés (0%)
#
# ==Récupération codes postaux: 8/91==
# 0/29 éléments récupérés (0%)
#
# ==Récupération codes postaux: 9/91==
# No data found from the query.
#
# ==Récupération codes postaux: 10/91==
# No data found from the query.
#
# ==Récupération codes postaux: 11/91==
# No data found from the query.
#
# ==Récupération codes postaux: 12/91==
# No data found from the query.
#
# ==Récupération codes postaux: 13/91==
# 0/77 éléments récupérés (0%)
#
# ==Récupération codes postaux: 14/91==
# No data found from the query.
#
# ==Récupération codes postaux: 15/91==
# No data found from the query.
#
# ==Récupération codes postaux: 16/91==
# No data found from the query.
#
# ==Récupération codes postaux: 17/91==
# No data found from the query.
#
# ==Récupération codes postaux: 18/91==
# No data found from the query.
#
# ==Récupération codes postaux: 19/91==
# No data found from the query.
#
# ==Récupération codes postaux: 20/91==
# No data found from the query.
#
# ==Récupération codes postaux: 21/91==
# No data found from the query.
#
# ==Récupération codes postaux: 22/91==
# 0/35 éléments récupérés (0%)
#
# ==Récupération codes postaux: 23/91==
# No data found from the query.
#
# ==Récupération codes postaux: 24/91==
# No data found from the query.
#
# ==Récupération codes postaux: 25/91==
# No data found from the query.
#
# ==Récupération codes postaux: 26/91==
# No data found from the query.
#
# ==Récupération codes postaux: 27/91==
# No data found from the query.
#
# ==Récupération codes postaux: 28/91==
# No data found from the query.
#
# ==Récupération codes postaux: 29/91==
# No data found from the query.
#
# ==Récupération codes postaux: 30/91==
# No data found from the query.
#
# ==Récupération codes postaux: 31/91==
# No data found from the query.
#
# ==Récupération codes postaux: 32/91==
# 100/493 éléments récupérés (20%)
# 200/493 éléments récupérés (40%)
# 300/493 éléments récupérés (60%)
# 393/493 éléments récupérés (79%)
# 393/493 éléments récupérés (79%)
#
# ==Récupération codes postaux: 33/91==
# No data found from the query.
#
# ==Récupération codes postaux: 34/91==
# No data found from the query.
#
# ==Récupération codes postaux: 35/91==
# No data found from the query.
#
# ==Récupération codes postaux: 36/91==
# No data found from the query.
#
# ==Récupération codes postaux: 37/91==
# No data found from the query.
#
# ==Récupération codes postaux: 38/91==
# No data found from the query.
#
# ==Récupération codes postaux: 39/91==
# 0/9 éléments récupérés (0%)
#
# ==Récupération codes postaux: 40/91==
# No data found from the query.
#
# ==Récupération codes postaux: 41/91==
# No data found from the query.
#
# ==Récupération codes postaux: 42/91==
# No data found from the query.
#
# ==Récupération codes postaux: 43/91==
# No data found from the query.
#
# ==Récupération codes postaux: 44/91==
# No data found from the query.
#
# ==Récupération codes postaux: 45/91==
# No data found from the query.
#
# ==Récupération codes postaux: 46/91==
# No data found from the query.
#
# ==Récupération codes postaux: 47/91==
# 0/19 éléments récupérés (0%)
#
# ==Récupération codes postaux: 48/91==
# No data found from the query.
#
# ==Récupération codes postaux: 49/91==
# No data found from the query.
#
# ==Récupération codes postaux: 50/91==
# No data found from the query.
#
# ==Récupération codes postaux: 51/91==
# No data found from the query.
#
# ==Récupération codes postaux: 52/91==
# No data found from the query.
#
# ==Récupération codes postaux: 53/91==
# 0/83 éléments récupérés (0%)
#
# ==Récupération codes postaux: 54/91==
# No data found from the query.
#
# ==Récupération codes postaux: 55/91==
# No data found from the query.
#
# ==Récupération codes postaux: 56/91==
# No data found from the query.
#
# ==Récupération codes postaux: 57/91==
# No data found from the query.
#
# ==Récupération codes postaux: 58/91==
# No data found from the query.
#
# ==Récupération codes postaux: 59/91==
# No data found from the query.
#
# ==Récupération codes postaux: 60/91==
# No data found from the query.
#
# ==Récupération codes postaux: 61/91==
# No data found from the query.
#
# ==Récupération codes postaux: 62/91==
# 100/3960 éléments récupérés (2%)
# 200/3960 éléments récupérés (5%)
# 300/3960 éléments récupérés (7%)
# 400/3960 éléments récupérés (10%)
# 500/3960 éléments récupérés (12%)
# 600/3960 éléments récupérés (15%)
# 700/3960 éléments récupérés (17%)
# 800/3960 éléments récupérés (20%)
# 900/3960 éléments récupérés (22%)
# 1000/3960 éléments récupérés (25%)
# 1100/3960 éléments récupérés (27%)
# 1200/3960 éléments récupérés (30%)
# 1300/3960 éléments récupérés (32%)
# 1400/3960 éléments récupérés (35%)
# 1500/3960 éléments récupérés (37%)
# 1600/3960 éléments récupérés (40%)
# 1700/3960 éléments récupérés (42%)
# 1800/3960 éléments récupérés (45%)
# 1900/3960 éléments récupérés (47%)
# 2000/3960 éléments récupérés (50%)
# 2100/3960 éléments récupérés (53%)
# 2200/3960 éléments récupérés (55%)
# 2300/3960 éléments récupérés (58%)
# 2400/3960 éléments récupérés (60%)
# 2500/3960 éléments récupérés (63%)
# 2600/3960 éléments récupérés (65%)
# 2700/3960 éléments récupérés (68%)
# 2800/3960 éléments récupérés (70%)
# 2900/3960 éléments récupérés (73%)
# 3000/3960 éléments récupérés (75%)
# 3100/3960 éléments récupérés (78%)
# 3200/3960 éléments récupérés (80%)
# 3300/3960 éléments récupérés (83%)
# 3400/3960 éléments récupérés (85%)
# 3500/3960 éléments récupérés (88%)
# 3600/3960 éléments récupérés (90%)
# 3700/3960 éléments récupérés (93%)
# 3800/3960 éléments récupérés (95%)
# 3860/3960 éléments récupérés (97%)
# 3860/3960 éléments récupérés (97%)
#
# ==Récupération codes postaux: 63/91==
# No data found from the query.
#
# ==Récupération codes postaux: 64/91==
# No data found from the query.
#
# ==Récupération codes postaux: 65/91==
# 0/1 éléments récupérés (0%)
#
# ==Récupération codes postaux: 66/91==
# 0/47 éléments récupérés (0%)
#
# ==Récupération codes postaux: 67/91==
# No data found from the query.
#
# ==Récupération codes postaux: 68/91==
# No data found from the query.
#
# ==Récupération codes postaux: 69/91==
# No data found from the query.
#
# ==Récupération codes postaux: 70/91==
# No data found from the query.
#
# ==Récupération codes postaux: 71/91==
# No data found from the query.
#
# ==Récupération codes postaux: 72/91==
# No data found from the query.
#
# ==Récupération codes postaux: 73/91==
# No data found from the query.
#
# ==Récupération codes postaux: 74/91==
# No data found from the query.
#
# ==Récupération codes postaux: 75/91==
# No data found from the query.
#
# ==Récupération codes postaux: 76/91==
# No data found from the query.
#
# ==Récupération codes postaux: 77/91==
# No data found from the query.
#
# ==Récupération codes postaux: 78/91==
# No data found from the query.
#
# ==Récupération codes postaux: 79/91==
# No data found from the query.
#
# ==Récupération codes postaux: 80/91==
# No data found from the query.
#
# ==Récupération codes postaux: 81/91==
# No data found from the query.
#
# ==Récupération codes postaux: 82/91==
# No data found from the query.
#
# ==Récupération codes postaux: 83/91==
# No data found from the query.
#
# ==Récupération codes postaux: 84/91==
# No data found from the query.
#
# ==Récupération codes postaux: 85/91==
# 100/248 éléments récupérés (40%)
# 148/248 éléments récupérés (59%)
# 148/248 éléments récupérés (59%)
#
# ==Récupération codes postaux: 86/91==
# 100/205 éléments récupérés (48%)
# 105/205 éléments récupérés (51%)
# 105/205 éléments récupérés (51%)
#
# ==Récupération codes postaux: 87/91==
# No data found from the query.
#
# ==Récupération codes postaux: 88/91==
# No data found from the query.
#
# ==Récupération codes postaux: 89/91==
# No data found from the query.
#
# ==Récupération codes postaux: 90/91==
# No data found from the query.
#
# ==Récupération codes postaux: 91/91==
# 0/3 éléments récupérés (0%)

# %%
pd.DataFrame(enedis_data)
# Out:
#      annee  code_iris                        nom_iris  numero_de_voie  \
# 0     2023  691700000   Rontalon (commune non irisée)              40
# 1     2019  691700000   Rontalon (commune non irisée)              40
# 2     2020  691700000   Rontalon (commune non irisée)              40
# 3     2021  691700000   Rontalon (commune non irisée)              40
# 4     2024  691700000   Rontalon (commune non irisée)              40
# ...    ...        ...                             ...             ...
# 5692  2022  692600000  Vernaison (commune non irisée)               7
# 5693  2022  692600000  Vernaison (commune non irisée)               3
# 5694  2022  691260000      Marcy (commune non irisée)             125
# 5695  2024  691260000      Marcy (commune non irisée)             125
# 5696  2023  691260000      Marcy (commune non irisée)             125
#
#      indice_de_repetition type_de_voie libelle_de_voie code_commune  \
# 0                    None        ROUTE     DE FONDRIEU        69170
# 1                    None        ROUTE     DE FONDRIEU        69170
# 2                    None        ROUTE     DE FONDRIEU        69170
# 3                    None        ROUTE     DE FONDRIEU        69170
# 4                    None        ROUTE     DE FONDRIEU        69170
# ...                   ...          ...             ...          ...
# 5692                 None          RUE     DU PERONNET        69260
# 5693                 None          RUE     DU PERONNET        69260
# 5694                 None        ROUTE    DE FRONTENAS        69126
# 5695                 None        ROUTE    DE FRONTENAS        69126
# 5696                 None        ROUTE    DE FRONTENAS        69126
#
#      nom_commune segment_de_client  nombre_de_logements  \
# 0       Rontalon       RESIDENTIEL                   19
# 1       Rontalon       RESIDENTIEL                   19
# 2       Rontalon       RESIDENTIEL                   19
# 3       Rontalon       RESIDENTIEL                   19
# 4       Rontalon       RESIDENTIEL                   19
# ...          ...               ...                  ...
# 5692   Vernaison       RESIDENTIEL                   24
# 5693   Vernaison       RESIDENTIEL                   21
# 5694       Marcy       RESIDENTIEL                   11
# 5695       Marcy       RESIDENTIEL                   12
# 5696       Marcy       RESIDENTIEL                   12
#
#       consommation_annuelle_totale_de_l_adresse_mwh  \
# 0                                            28.373
# 1                                            39.701
# 2                                            38.007
# 3                                            38.119
# 4                                            32.556
# ...                                             ...
# 5692                                         45.285
# 5693                                         42.657
# 5694                                         79.578
# 5695                                         99.043
# 5696                                         98.606
#
#       consommation_annuelle_moyenne_par_site_de_l_adresse_mwh  \
# 0                                                 1.493
# 1                                                 2.090
# 2                                                 2.000
# 3                                                 2.006
# 4                                                 1.713
# ...                                                 ...
# 5692                                              1.887
# 5693                                              2.031
# 5694                                              7.234
# 5695                                              8.254
# 5696                                              8.217
#
#       consommation_annuelle_moyenne_de_la_commune_mwh                 adresse  \
# 0                                               5.578    40 ROUTE DE FONDRIEU
# 1                                               6.380    40 ROUTE DE FONDRIEU
# 2                                               6.391    40 ROUTE DE FONDRIEU
# 3                                               6.633    40 ROUTE DE FONDRIEU
# 4                                               5.657    40 ROUTE DE FONDRIEU
# ...                                               ...                     ...
# 5692                                            5.492       7 RUE DU PERONNET
# 5693                                            5.492       3 RUE DU PERONNET
# 5694                                            8.258  125 ROUTE DE FRONTENAS
# 5695                                            7.696  125 ROUTE DE FRONTENAS
# 5696                                            7.791  125 ROUTE DE FRONTENAS
#
#       code_epci code_departement code_region  tri_des_adresses
# 0     246900740               69          84            306339
# 1     246900740               69          84            309872
# 2     246900740               69          84            314051
# 3     246900740               69          84            314961
# 4     246900740               69          84            329504
# ...         ...              ...         ...               ...
# 5692  200046977               69          84            370615
# 5693  200046977               69          84            370617
# 5694  200040574               69          84            174940
# 5695  200040574               69          84            190848
# 5696  200040574               69          84            176747
#
# [5697 rows x 19 columns]
